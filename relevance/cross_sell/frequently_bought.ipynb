# %%
import pandas as pd
import numpy as np

# %%
# read sample transaction data
data = pd.read_csv('../../data/transaction_data_sample.csv')
data.head(2)
# Out:
#         t_dat                                        customer_id  article_id  \
# 0  2018-09-20  001ea4e9c54f7e9c88811260d954edc059d596147e1cf8...   652075001
# 1  2018-09-20  001ea4e9c54f7e9c88811260d954edc059d596147e1cf8...   670295001
#
#       price
# 0  0.011847
# 1  0.010153

# %%
# read item metadata for reference
items = pd.read_csv('../../data/articles.csv')
items = items[['article_id', 'prod_name', 'product_type_name', 'product_group_name', 
                     'graphical_appearance_name', 'index_group_name', 'section_name',
                     'colour_group_name', 'perceived_colour_value_name']].copy()

# combining all columns except the id and performing ordered deduplication
items['combined'] = items.iloc[:,1:].agg(' '.join, axis=1)
items = items[['article_id', 'combined']].copy()

items.head(2)
# Out:
#    article_id                                           combined
# 0   108775015  Strap top Vest top Garment Upper body Solid La...
# 1   108775044  Strap top Vest top Garment Upper body Solid La...

# %%
i2i = data[['customer_id', 'article_id']].copy()
i2i = i2i.merge(items[['article_id', 'combined']], on=['article_id'], how='left')
pidcount = dict(i2i.groupby(['article_id']).size().reset_index(name='count').values)

i2i = i2i.merge(i2i, on=['customer_id'])
i2i = i2i[i2i['article_id_x'] != i2i['article_id_y']].copy()
i2i.head(2)
# Out:
#                                          customer_id  article_id_x  \
# 1  001ea4e9c54f7e9c88811260d954edc059d596147e1cf8...     652075001
# 2  001ea4e9c54f7e9c88811260d954edc059d596147e1cf8...     652075001
#
#                                           combined_x  article_id_y  \
# 1  Stork fancy T-shirt Garment Upper body Solid D...     670295001
# 2  Stork fancy T-shirt Garment Upper body Solid D...     678153002
#
#                                           combined_y
# 1  CSP Hackney tank Vest top Garment Upper body S...
# 2  Stud Jumper Sweater Garment Upper body Melange...

# %% [markdown]
# # Co-occurence

# %%
i2i = i2i.groupby(['article_id_x', 'article_id_y', 'combined_x', 'combined_y']).size().reset_index(name='co_occurence')
i2i = i2i[i2i['co_occurence'] > 1].copy()
co_occurence = i2i.sort_values(['article_id_x', 'co_occurence'], ascending=[True, False]).groupby(['article_id_x'], sort=False).head(10)

# %%
co_occurence = data[['customer_id', 'article_id']].drop_duplicates().merge(co_occurence.rename(columns={"article_id_x": 'article_id'}), on=['article_id'])

co_occurence = co_occurence.groupby(["customer_id", "article_id_y"]).agg({"co_occurence": "sum"}).reset_index()

co_occurence = co_occurence[['customer_id', 'article_id_y', 'co_occurence']].rename(columns={'article_id_y': 'article_id'})
co_occurence.sort_values(["customer_id", "co_occurence"], ascending=[True, False], inplace=True)
co_occurence.head()
# Out:
#                                           customer_id  article_id  \
# 60  000fa62c9e64d11bc25c530736949fd8dfc9a39d50c453...   706016002
# 61  000fa62c9e64d11bc25c530736949fd8dfc9a39d50c453...   706016003
# 63  000fa62c9e64d11bc25c530736949fd8dfc9a39d50c453...   706016015
# 62  000fa62c9e64d11bc25c530736949fd8dfc9a39d50c453...   706016006
# 29  000fa62c9e64d11bc25c530736949fd8dfc9a39d50c453...   539723001
#
#     co_occurence
# 60           184
# 61           101
# 63            81
# 62            66
# 29            56

# %%
co_occurence.to_csv('./co_occurence_recommendation.csv', index=False)

# %% [markdown]
# # Collaborative Filtering

# %%
i2i['union'] = i2i['article_id_x'].map(pidcount) +  i2i['article_id_y'].map(pidcount) - i2i['co_occurence']

i2i['cf_score'] = i2i['co_occurence'] / i2i['union']
i2i = i2i.sort_values(['article_id_x', 'cf_score'], ascending=[True, False]).groupby(['article_id_x'], sort=False).head(10)

i2i.head(2)
# Out:
#      article_id_x  article_id_y  \
# 0       108775015     108775044
# 339     108775015     538699001
#
#                                             combined_x  \
# 0    Strap top Vest top Garment Upper body Solid La...
# 339  Strap top Vest top Garment Upper body Solid La...
#
#                                             combined_y  co_occurence  union  \
# 0    Strap top Vest top Garment Upper body Solid La...            14    122
# 339  V-neck strap top Vest top Garment Upper body S...            16    147
#
#      cf_score
# 0    0.114754
# 339  0.108844

# %%
cf = data[['customer_id', 'article_id']].drop_duplicates().merge(i2i.rename(columns={"article_id_x": 'article_id'}), on=['article_id'])

cf = cf.groupby(["customer_id", "article_id_y"]).agg({"co_occurence": "sum", "union": "sum"}).reset_index()
cf["cf_score"] = cf["co_occurence"] / cf["union"]

cf = cf[['customer_id', 'article_id_y', 'cf_score']].rename(columns={'article_id_y': 'article_id'})
cf.sort_values(["customer_id", "cf_score"], ascending=[True, False], inplace=True)
cf.head()
# Out:
#                                           customer_id  article_id  cf_score
# 15  000fa62c9e64d11bc25c530736949fd8dfc9a39d50c453...   524529010  0.240000
# 42  000fa62c9e64d11bc25c530736949fd8dfc9a39d50c453...   706016002  0.232759
# 71  000fa62c9e64d11bc25c530736949fd8dfc9a39d50c453...   789060001  0.222222
# 19  000fa62c9e64d11bc25c530736949fd8dfc9a39d50c453...   554479005  0.217105
# 93  000fa62c9e64d11bc25c530736949fd8dfc9a39d50c453...   909924001  0.181818

# %%
cf.to_csv('./collaborative_filtering.csv', index=False)

# %% [markdown]
# # Qualitative Analyis

# %% [markdown]
# #### Co-occurence

# %%
co_occurence[co_occurence['article_id_x']==108775015].head()
# Out:
#      article_id_x  article_id_y  \
# 339     108775015     538699001
# 0       108775015     108775044
# 92      108775015     372860001
# 340     108775015     538699007
# 407     108775015     554772002
#
#                                             combined_x  \
# 339  Strap top Vest top Garment Upper body Solid La...
# 0    Strap top Vest top Garment Upper body Solid La...
# 92   Strap top Vest top Garment Upper body Solid La...
# 340  Strap top Vest top Garment Upper body Solid La...
# 407  Strap top Vest top Garment Upper body Solid La...
#
#                                             combined_y  co_occurence
# 339  V-neck strap top Vest top Garment Upper body S...            16
# 0    Strap top Vest top Garment Upper body Solid La...            14
# 92   7p Basic Shaftless Socks Socks & Tights Solid ...            12
# 340  V-neck strap top Vest top Garment Upper body S...             9
# 407  Bob V-neck T-shirt Garment Upper body Solid La...             9

# %%
co_occurence[co_occurence['article_id_x']==722416001].head()
# Out:
#          article_id_x  article_id_y  \
# 6770762     722416001     616711011
# 6770791     722416001     664122002
# 6770737     722416001     294008002
# 6770751     722416001     573085044
# 6770770     722416001     617828002
#
#                                                 combined_x  \
# 6770762  DIV Xena jacket Blazer Garment Upper body Soli...
# 6770791  DIV Xena jacket Blazer Garment Upper body Soli...
# 6770737  DIV Xena jacket Blazer Garment Upper body Soli...
# 6770751  DIV Xena jacket Blazer Garment Upper body Soli...
# 6770770  DIV Xena jacket Blazer Garment Upper body Soli...
#
#                                                 combined_y  co_occurence
# 6770762  ED Baraboom cardigan Cardigan Garment Upper bo...             3
# 6770791  &DENIM Shaping bootcut Trousers Garment Lower ...             3
# 6770737  HM+ Cora tee Costumes Garment Full body Solid ...             2
# 6770751  Madison skinny HW (1) Trousers Garment Lower b...             2
# 6770770  DIV Charlie Aline skirt Skirt Garment Lower bo...             2

# %% [markdown]
# #### Collaborative Filtering

# %%
i2i[i2i['article_id_x']==108775015].head()
# Out:
#       article_id_x  article_id_y  \
# 0        108775015     108775044
# 339      108775015     538699001
# 340      108775015     538699007
# 1123     108775015     670691003
# 407      108775015     554772002
#
#                                              combined_x  \
# 0     Strap top Vest top Garment Upper body Solid La...
# 339   Strap top Vest top Garment Upper body Solid La...
# 340   Strap top Vest top Garment Upper body Solid La...
# 1123  Strap top Vest top Garment Upper body Solid La...
# 407   Strap top Vest top Garment Upper body Solid La...
#
#                                              combined_y  co_occurence  union  \
# 0     Strap top Vest top Garment Upper body Solid La...            14    122
# 339   V-neck strap top Vest top Garment Upper body S...            16    147
# 340   V-neck strap top Vest top Garment Upper body S...             9    120
# 1123  PE HEIDI CASHMERE Sweater Garment Upper body S...             6     81
# 407   Bob V-neck T-shirt Garment Upper body Solid La...             9    126
#
#       cf_score
# 0     0.114754
# 339   0.108844
# 340   0.075000
# 1123  0.074074
# 407   0.071429

# %%
i2i[i2i['article_id_x']==722416001].head()
# Out:
#          article_id_x  article_id_y  \
# 6770791     722416001     664122002
# 6770837     722416001     749665002
# 6770857     722416001     780204001
# 6770770     722416001     617828002
# 6770776     722416001     627108001
#
#                                                 combined_x  \
# 6770791  DIV Xena jacket Blazer Garment Upper body Soli...
# 6770837  DIV Xena jacket Blazer Garment Upper body Soli...
# 6770857  DIV Xena jacket Blazer Garment Upper body Soli...
# 6770770  DIV Xena jacket Blazer Garment Upper body Soli...
# 6770776  DIV Xena jacket Blazer Garment Upper body Soli...
#
#                                                 combined_y  co_occurence  \
# 6770791  &DENIM Shaping bootcut Trousers Garment Lower ...             3
# 6770837  &DENIM Embrace denim shorts Shorts Garment Low...             2
# 6770857  DIV Boy denim shorts Shorts Garment Lower body...             2
# 6770770  DIV Charlie Aline skirt Skirt Garment Lower bo...             2
# 6770776  Amy padded bra BIG Bra Underwear Solid Ladiesw...             2
#
#          union  cf_score
# 6770791      4  0.750000
# 6770837      3  0.666667
# 6770857      3  0.666667
# 6770770      4  0.500000
# 6770776      4  0.500000
