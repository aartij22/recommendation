# %%
import pandas as pd
import numpy as np

# %%
# read sample transaction data
data = pd.read_csv("../../data/transactions.csv")
data.head(2)
# Out:
#         t_dat                                        customer_id  article_id  \
# 0  2018-09-20  001ea4e9c54f7e9c88811260d954edc059d596147e1cf8...   652075001
# 1  2018-09-20  001ea4e9c54f7e9c88811260d954edc059d596147e1cf8...   670295001
#
#       price
# 0  0.011847
# 1  0.010153

# %%
# read item metadata for reference
items = pd.read_csv("../../data/articles.csv")
items = items[
    [
        "article_id",
        "prod_name",
        "product_type_name",
        "product_group_name",
        "graphical_appearance_name",
        "index_group_name",
        "section_name",
        "colour_group_name",
        "perceived_colour_value_name",
    ]
].copy()

# combining all columns except the id and performing ordered deduplication
items["combined"] = items.iloc[:, 1:].agg(" ".join, axis=1)
items = items[["article_id", "combined"]].copy()

items.head(2)
# Out:
#    article_id                                           combined
# 0   108775015  Strap top Vest top Garment Upper body Solid La...
# 1   108775044  Strap top Vest top Garment Upper body Solid La...

# %%
i2i = data[["customer_id", "article_id"]].copy()
i2i = i2i.merge(items[["article_id", "combined"]], on=["article_id"], how="left")
pidcount = dict(i2i.groupby(["article_id"]).size().reset_index(name="count").values)

i2i = i2i.merge(i2i, on=["customer_id"])
i2i = i2i[i2i["article_id_x"] != i2i["article_id_y"]].copy()
i2i.head(2)
# Out:
#                                          customer_id  article_id_x  \
# 1  001ea4e9c54f7e9c88811260d954edc059d596147e1cf8...     652075001
# 2  001ea4e9c54f7e9c88811260d954edc059d596147e1cf8...     652075001
#
#                                           combined_x  article_id_y  \
# 1  Stork fancy T-shirt Garment Upper body Solid D...     670295001
# 2  Stork fancy T-shirt Garment Upper body Solid D...     678153002
#
#                                           combined_y
# 1  CSP Hackney tank Vest top Garment Upper body S...
# 2  Stud Jumper Sweater Garment Upper body Melange...

# %% [markdown]
# # Co-occurence

# %%
i2i = (
    i2i.groupby(["article_id_x", "article_id_y", "combined_x", "combined_y"])
    .size()
    .reset_index(name="co_occurence")
)
i2i = i2i[i2i["co_occurence"] > 1].copy()
co_occur = (
    i2i.sort_values(["article_id_x", "co_occurence"], ascending=[True, False])
    .groupby(["article_id_x"], sort=False)
    .head(10)
)

# %%
co_occurence = (
    data[["customer_id", "article_id"]]
    .drop_duplicates()
    .merge(co_occur.rename(columns={"article_id_x": "article_id"}), on=["article_id"])
)

co_occurence = (
    co_occurence.groupby(["customer_id", "article_id_y"])
    .agg({"co_occurence": "sum"})
    .reset_index()
)

co_occurence = co_occurence[["customer_id", "article_id_y", "co_occurence"]].rename(
    columns={"article_id_y": "article_id"}
)
co_occurence.sort_values(
    ["customer_id", "co_occurence"], ascending=[True, False], inplace=True
)
co_occurence.head()
# Out:
#                                           customer_id  article_id  \
# 60  000fa62c9e64d11bc25c530736949fd8dfc9a39d50c453...   706016002
# 61  000fa62c9e64d11bc25c530736949fd8dfc9a39d50c453...   706016003
# 63  000fa62c9e64d11bc25c530736949fd8dfc9a39d50c453...   706016015
# 62  000fa62c9e64d11bc25c530736949fd8dfc9a39d50c453...   706016006
# 29  000fa62c9e64d11bc25c530736949fd8dfc9a39d50c453...   539723001
#
#     co_occurence
# 60           184
# 61           101
# 63            81
# 62            66
# 29            56

# %%
co_occurence.to_csv("./co_occurence_recommendation.csv", index=False)

# %% [markdown]
# # Collaborative Filtering

# %%
i2i["union"] = (
    i2i["article_id_x"].map(pidcount)
    + i2i["article_id_y"].map(pidcount)
    - i2i["co_occurence"]
)

i2i["cf_score"] = i2i["co_occurence"] / i2i["union"]
i2i = (
    i2i.sort_values(["article_id_x", "cf_score"], ascending=[True, False])
    .groupby(["article_id_x"], sort=False)
    .head(10)
)

i2i.head(2)
# Out:
#      article_id_x  article_id_y  \
# 0       108775015     108775044
# 339     108775015     538699001
#
#                                             combined_x  \
# 0    Strap top Vest top Garment Upper body Solid La...
# 339  Strap top Vest top Garment Upper body Solid La...
#
#                                             combined_y  co_occurence  union  \
# 0    Strap top Vest top Garment Upper body Solid La...            14    122
# 339  V-neck strap top Vest top Garment Upper body S...            16    147
#
#      cf_score
# 0    0.114754
# 339  0.108844

# %%
cf = (
    data[["customer_id", "article_id"]]
    .drop_duplicates()
    .merge(i2i.rename(columns={"article_id_x": "article_id"}), on=["article_id"])
)

cf = (
    cf.groupby(["customer_id", "article_id_y"])
    .agg({"co_occurence": "sum", "union": "sum"})
    .reset_index()
)
cf["cf_score"] = cf["co_occurence"] / cf["union"]

cf = cf[["customer_id", "article_id_y", "cf_score"]].rename(
    columns={"article_id_y": "article_id"}
)
cf.sort_values(["customer_id", "cf_score"], ascending=[True, False], inplace=True)
cf.head()
# Out:
#                                           customer_id  article_id  cf_score
# 15  000fa62c9e64d11bc25c530736949fd8dfc9a39d50c453...   524529010  0.240000
# 42  000fa62c9e64d11bc25c530736949fd8dfc9a39d50c453...   706016002  0.232759
# 71  000fa62c9e64d11bc25c530736949fd8dfc9a39d50c453...   789060001  0.222222
# 19  000fa62c9e64d11bc25c530736949fd8dfc9a39d50c453...   554479005  0.217105
# 93  000fa62c9e64d11bc25c530736949fd8dfc9a39d50c453...   909924001  0.181818

# %%
cf.to_csv("./collaborative_filtering.csv", index=False)

# %% [markdown]
# # Qualitative Analyis

# %% [markdown]
# ##### Co-occurence

# %%
co_occur[co_occur["article_id_x"] == 776237011].head()
# Out:
#          article_id_x  article_id_y  \
# 9169438     776237011     599580038
# 9170556     776237011     776237006
# 9170739     776237011     806225008
# 9169070     776237011     351484002
# 9169444     776237011     599580052
#
#                                                 combined_x  \
# 9169438  Shake it in Balconette Bikini top Swimwear Sol...
# 9170556  Shake it in Balconette Bikini top Swimwear Sol...
# 9170739  Shake it in Balconette Bikini top Swimwear Sol...
# 9169070  Shake it in Balconette Bikini top Swimwear Sol...
# 9169444  Shake it in Balconette Bikini top Swimwear Sol...
#
#                                                 combined_y  co_occurence
# 9169438  Timeless Midrise Brief Swimwear bottom Swimwea...            57
# 9170556  Shake it in Balconette Bikini top Swimwear Sol...            10
# 9170739  All That Jazz Push Up Bra Bikini top Swimwear ...            10
# 9169070  Lazer Razer Brief Swimwear bottom Swimwear Sol...             9
# 9169444  Timeless Midrise Brief Swimwear bottom Swimwea...             9

# %%
co_occur[co_occur["article_id_x"] == 608776002].head()
# Out:
#          article_id_x  article_id_y  \
# 2480841     608776002     372860001
# 2480842     608776002     372860002
# 2480680     608776002     160442007
# 2480665     608776002     111586001
# 2481992     608776002     608776003
#
#                                                 combined_x  \
# 2480841  Scallop 5p Socks Socks Socks & Tights Solid La...
# 2480842  Scallop 5p Socks Socks Socks & Tights Solid La...
# 2480680  Scallop 5p Socks Socks Socks & Tights Solid La...
# 2480665  Scallop 5p Socks Socks Socks & Tights Solid La...
# 2481992  Scallop 5p Socks Socks Socks & Tights Solid La...
#
#                                                 combined_y  co_occurence
# 2480841  7p Basic Shaftless Socks Socks & Tights Solid ...            49
# 2480842  7p Basic Shaftless Socks Socks & Tights Solid ...            29
# 2480680  3p Sneaker Socks Socks Socks & Tights Solid La...            22
# 2480665  Shape Up 30 den 1p Tights Leggings/Tights Garm...            17
# 2481992  Scallop 5p Socks Socks Socks & Tights Contrast...            17

# %% [markdown]
# ##### Collaborative Filtering

# %%
i2i[i2i["article_id_x"] == 776237011].head()
# Out:
#          article_id_x  article_id_y  \
# 9169438     776237011     599580038
# 9170739     776237011     806225008
# 9170556     776237011     776237006
# 9169344     776237011     571706010
# 9169569     776237011     633778001
#
#                                                 combined_x  \
# 9169438  Shake it in Balconette Bikini top Swimwear Sol...
# 9170739  Shake it in Balconette Bikini top Swimwear Sol...
# 9170556  Shake it in Balconette Bikini top Swimwear Sol...
# 9169344  Shake it in Balconette Bikini top Swimwear Sol...
# 9169569  Shake it in Balconette Bikini top Swimwear Sol...
#
#                                                 combined_y  co_occurence  \
# 9169438  Timeless Midrise Brief Swimwear bottom Swimwea...            57
# 9170739  All That Jazz Push Up Bra Bikini top Swimwear ...            10
# 9170556  Shake it in Balconette Bikini top Swimwear Sol...            10
# 9169344  Timeless High Rise Hipster Swimwear bottom Swi...             7
# 9169569  Halloween SPEED A-band Bat Hair/alice band Acc...             6
#
#          union  cf_score
# 9169438    108  0.527778
# 9170739     87  0.114943
# 9170556     92  0.108696
# 9169344     74  0.094595
# 9169569     68  0.088235

# %%
i2i[i2i["article_id_x"] == 608776002].head()
# Out:
#          article_id_x  article_id_y  \
# 2480841     608776002     372860001
# 2485325     608776002     761968002
# 2481992     608776002     608776003
# 2480842     608776002     372860002
# 2480680     608776002     160442007
#
#                                                 combined_x  \
# 2480841  Scallop 5p Socks Socks Socks & Tights Solid La...
# 2485325  Scallop 5p Socks Socks Socks & Tights Solid La...
# 2481992  Scallop 5p Socks Socks Socks & Tights Solid La...
# 2480842  Scallop 5p Socks Socks Socks & Tights Solid La...
# 2480680  Scallop 5p Socks Socks Socks & Tights Solid La...
#
#                                                 combined_y  co_occurence  \
# 2480841  7p Basic Shaftless Socks Socks & Tights Solid ...            49
# 2485325  Elisabeth dress (1) Dress Garment Full body So...            15
# 2481992  Scallop 5p Socks Socks Socks & Tights Contrast...            17
# 2480842  7p Basic Shaftless Socks Socks & Tights Solid ...            29
# 2480680  3p Sneaker Socks Socks Socks & Tights Solid La...            22
#
#          union  cf_score
# 2480841    567  0.086420
# 2485325    239  0.062762
# 2481992    279  0.060932
# 2480842    514  0.056420
# 2480680    409  0.053790
